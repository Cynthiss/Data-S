# %% [markdown]
# # Linear Regression Model
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset
data = pd.read_csv('linear_regression_dataset.csv')
X = data['X'].values
Y = data['Y'].values

# Visualize dataset
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Dataset Visualization')
plt.show()

# %%
# MSE and R-squared

# Simple linear regression prediction 
w, b = 2.5, 5 #(arbitrary weights for demo)
Y_pred = w * X + b

# Mean Squared Error (MSE)
mse = np.mean((Y - Y_pred) ** 2)

# R-squared calculation
ss_residual = np.sum((Y - Y_pred) ** 2)
ss_total = np.sum((Y - np.mean(Y)) ** 2)
r_squared = 1 - (ss_residual / ss_total)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared: {r_squared:.4f}")
# Out:
# Mean Squared Error (MSE): 8.15
# R-squared: 0.9611

# %%
# Gradient Descent

# Initialize parameters
w, b = 0, 0  # Initial weights and bias
learning_rate = 0.0002
epochs = 100
n = len(X)

# Store history for visualization
loss_history = []

for epoch in range(epochs):
    
    # Predictions
    Y_pred = w * X + b
    
    # Calculate and store loss (MSE)
    loss = np.mean((Y - Y_pred) ** 2)
    loss_history.append(loss)

    # Calculate gradients
    dw = -(2/n) * np.sum((Y - Y_pred) * X)
    db = -(2/n) * np.sum(Y - Y_pred)
    
    # Update weights and bias
    w -= learning_rate * dw
    b -= learning_rate * db


# Final parameters
print(f"Final weight: {w:.4f}, Final bias: {b:.4f}")


# Plotting the loss over epochs
plt.plot(loss_history)
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Loss over Time')
plt.show()


# Plotting the regression line
plt.scatter(X, Y, label='Data')
plt.plot(X, w * X + b, color='red', label='Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
# Out:
# Final weight: 2.7695, Final bias: 0.2571

# %%
loss_history
# Out:
# [np.float64(1069.310184688027),
#  np.float64(958.0452216430452),
#  np.float64(858.5091425482165),
#  np.float64(769.4655443957879),
#  np.float64(689.8083598893146),
#  np.float64(618.5481180742657),
#  np.float64(554.7996533074595),
#  np.float64(497.77110988834977),
#  np.float64(446.754105769668),
#  np.float64(401.1149331628037),
#  np.float64(360.28668673341775),
#  np.float64(323.7622216051513),
#  np.float64(291.0878536970154),
#  np.float64(261.85772414118367),
#  np.float64(235.7087577769966),
#  np.float64(212.31615309649627),
#  np.float64(191.38934761840358),
#  np.float64(172.66840857313878),
#  np.float64(155.92080406462148),
#  np.float64(140.93851460080293),
#  np.float64(127.53544911287985),
#  np.float64(115.54513336544584),
#  np.float64(104.81864204342551),
#  np.float64(95.22274882854651),
#  np.float64(86.63827148593126),
#  np.float64(78.95859140377186),
#  np.float64(72.0883291960753),
#  np.float64(65.94215991705373),
#  np.float64(60.44375316996599),
#  np.float64(55.524824944633295),
#  np.float64(51.12428940572349),
#  np.float64(47.18750009547174),
#  np.float64(43.66557112519271),
#  np.float64(40.514769923548286),
#  np.float64(37.695973998397875),
#  np.float64(35.174184964224956),
#  np.float64(32.91809379847599),
#  np.float64(30.89969192650351),
#  np.float64(29.093923304080445),
#  np.float64(27.478373175717834),
#  np.float64(26.03298964259639),
#  np.float64(24.73983458148011),
#  np.float64(23.582860820570087),
#  np.float64(22.547712804418033),
#  np.float64(21.6215482717944),
#  np.float64(20.79287873142534),
#  np.float64(20.051426754017324),
#  np.float64(19.387998307876117),
#  np.float64(18.79436855229619),
#  np.float64(18.263179670066812),
